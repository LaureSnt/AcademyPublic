# %% [markdown]
# <a href="https://colab.research.google.com/github/LaureSnt/AcademyPublic/blob/main/Session%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hello

# %%
# !pip install -q kaggle
from google.colab import files
files.upload()
#create a kaggle folder
# !mkdir ~/.kaggle
# Go on kaggle > Account > Create New API token
# Save the json file in your laptop in a dedicated folder
# copy the kaggle.json to folder created
# !cp kaggle.json ~/.kaggle
#permission for the json to act
# !chmod 600 ~/.kaggle/kaggle.json
# Datasets available here: 
# https://www.kaggle.com/avikpaul4u/vehicle-loan-default-prediction
# !kaggle datasets download -d avikpaul4u/vehicle-loan-default-prediction
# !unzip vehicle-loan-default-prediction.zip
# https://www.kaggle.com/uciml/red-wine-quality-cortez-et-al-2009
# !kaggle datasets download -d uciml/red-wine-quality-cortez-et-al-2009
# !unzip red-wine-quality-cortez-et-al-2009.zip
# Out:
#      <input type="file" id="files-16dd5b6d-3c26-43ac-a894-a2fbe97de8ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16dd5b6d-3c26-43ac-a894-a2fbe97de8ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# ...
#   0% 0.00/11.6M [00:00<?, ?B/s]
# 100% 11.6M/11.6M [00:00<00:00, 220MB/s]
# Archive:  vehicle-loan-default-prediction.zip
#   inflating: Data Dictionary.xlsx
#   inflating: test.csv
#   inflating: train.csv
# ...
#   0% 0.00/25.6k [00:00<?, ?B/s]
# 100% 25.6k/25.6k [00:00<00:00, 20.6MB/s]
# Archive:  red-wine-quality-cortez-et-al-2009.zip
#   inflating: winequality-red.csv

# %%
import pandas as pd # Here I import a library named pandas which is specialized in
# data manipulation. I give an alias pd it is a kind of pseudonyme where pd refers to pandas.
import numpy as np
df = pd.read_csv('/content/winequality-red.csv')

df.head()

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/winequality-red.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.head(6)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# ...

# %%
df.tail(6)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# ...

# %%
df.sample(6)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1212            6.8             0.650         0.02             2.1      0.078
# 1498            6.6             0.895         0.04             2.3      0.068
# 1203            9.9             0.740         0.19             5.8      0.111
# 1039            8.9             0.500         0.21             2.2      0.088
# 1361            8.3             0.850         0.14             2.5      0.093
# 516            12.5             0.600         0.49             4.3      0.100
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1212                  8.0                  15.0  0.99498  3.35       0.62
# 1498                  7.0                  13.0  0.99582  3.53       0.58
# 1203                 33.0                  76.0  0.99878  3.14       0.55
# 1039                 21.0                  39.0  0.99692  3.33       0.83
# ...

# %%
df.sample(6, random_state=...)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-a8567d422bfb> in <module>()
# ----> 1 df.sample(6, random_state=...)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5282
#    5283         # Process random_state argument
# -> 5284         rs = com.random_state(random_state)
#    5285
#    5286         # Check weights for compliance
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/common.py in random_state(state)
#     430     else:
#     431         raise ValueError(
# --> 432             "random_state must be an integer, array-like, a BitGenerator, "
#     433             "a numpy RandomState, or None"
#     434         )
#
# ValueError: random_state must be an integer, array-like, a BitGenerator, a numpy RandomState, or None

# %%
df.dtypes #float means that datas are decimals, int means that this is nimbre entier, date time means dates , object means something else than numbers
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.describe() #data statistic
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.info() # see if datas are the one I want
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.shape #format
# Out:
# (1599, 12)

# %%
len(df) # lenght
# Out:
# 1599

# %%
df['fixed acidity'].head()
# Out:
# 0     7.4
# 1     7.8
# 2     7.8
# 3    11.2
# 4     7.4
# Name: fixed acidity, dtype: float64

# %%
df[['fixed acidity','volatile acidity']].head()
# Out:
#    fixed acidity  volatile acidity
# 0            7.4              0.70
# 1            7.8              0.88
# 2            7.8              0.76
# 3           11.2              0.28
# 4            7.4              0.70

# %%
df[['fixed acidity','volatile acidity','quality']].head()
# Out:
#    fixed acidity  volatile acidity  quality
# 0            7.4              0.70        5
# 1            7.8              0.88        5
# 2            7.8              0.76        5
# 3           11.2              0.28        6
# 4            7.4              0.70        5

# %%
mask1=df['fixed acidity']>7 #output type boolean --> True false answer

# %%
df[mask1]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1576            8.0              0.30         0.63             1.6      0.081
# 1580            7.4              0.35         0.33             2.4      0.068
# 1585            7.2              0.39         0.44             2.6      0.066
# 1586            7.5              0.31         0.41             2.4      0.065
# 1588            7.2              0.66         0.33             2.5      0.068
#
# ...

# %%
temp = df[mask1]

# %%
len(df)
# Out:
# 1599

# %%
len(temp)
# Out:
# 1237

# %%
df[mask1].min()
# Out:
# fixed acidity           7.10000
# volatile acidity        0.12000
# citric acid             0.00000
# residual sugar          0.90000
# chlorides               0.03800
# free sulfur dioxide     1.00000
# total sulfur dioxide    6.00000
# density                 0.99007
# pH                      2.74000
# sulphates               0.33000
# alcohol                 8.40000
# quality                 3.00000
# dtype: float64

# %%
mask2=df['fixed acidity'].between(7,8,inclusive='both')# Randomly it will always be included. but we can exclude either 7 or 8 or both with incluse = left, right , both, none

# %%
df[mask2]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 4               7.4              0.70         0.00             1.9      0.076
# 5               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1576            8.0              0.30         0.63             1.6      0.081
# 1580            7.4              0.35         0.33             2.4      0.068
# 1585            7.2              0.39         0.44             2.6      0.066
# 1586            7.5              0.31         0.41             2.4      0.065
# 1588            7.2              0.66         0.33             2.5      0.068
#
# ...

# %%
temp1=df[mask2]

# %%
df[mask2][['pH','quality']].sample(n=100, random_state=6242021).nunique()
# Out:
# pH         37
# quality     6
# dtype: int64

# %%
(df['residual sugar']<=1.9) | (df['residual sugar']>=2.3)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598     True
# Name: residual sugar, Length: 1599, dtype: bool

# %%
mask3=((df['residual sugar']<=1.9) | (df['residual sugar']>=2.3)) & (df['sulphates']<0.7301) #Filter python way
temp=df[mask3]
temp
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1582            6.1             0.715         0.10             2.6      0.053
# 1587            5.8             0.610         0.11             1.8      0.066
# 1589            6.6             0.725         0.20             7.8      0.073
# 1591            5.4             0.740         0.09             1.7      0.089
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
temp.max()
# Out:
# fixed acidity            15.6000
# volatile acidity          1.3300
# citric acid               0.7800
# residual sugar           15.5000
# chlorides                 0.3870
# free sulfur dioxide      72.0000
# total sulfur dioxide    289.0000
# density                   1.0032
# pH                        4.0100
# sulphates                 0.7300
# alcohol                  13.6000
# quality                   8.0000
# dtype: float64

# %%
len(temp)
# Out:
# 893

# %%
def citric_acid_cat(x):
  if x<0.21:
    return 'A'
  elif x<0.3:
    return 'B'
  else :
    return 'C'

# %%
df['NEW_NAME_citric_cat'] = df['citric acid'].apply(lambda x: citric_acid_cat(x))

# %%
df['NEW_NAME_citric_cat'].sample(n=5)
# Out:
# 1104    C
# 353     C
# 419     A
# 5       A
# 178     A
# Name: NEW_NAME_citric_cat, dtype: object

# %%
#df=df.drop(columns=['NEW_NAME_citric_cat']) --> remove columns

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# y                         int64
# NEW_NAME_citric_cat      object
# dtype: object

# %%
mask4=(((df['residual sugar']<=1.9) | (df['residual sugar']>=2.3)) & (df['sulphates']<0.7301) & (df['NEW_NAME_citric_cat'] !='A'))
df[mask4]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2              0.28         0.56             1.9      0.075
# 20              8.9              0.22         0.48             1.8      0.077
# 21              7.6              0.39         0.31             2.3      0.082
# 26              7.6              0.41         0.24             1.8      0.080
# 34              5.2              0.32         0.25             1.8      0.103
# ...             ...               ...          ...             ...        ...
# 1549            7.4              0.36         0.30             1.8      0.074
# 1558            6.9              0.63         0.33             6.7      0.235
# 1574            5.6              0.31         0.78            13.9      0.074
# 1580            7.4              0.35         0.33             2.4      0.068
# 1598            6.0              0.31         0.47             3.6      0.067
#
# ...

# %%
df['y'] = np.where(df['quality']>=6, 1, 0)
df.sample(n=5)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 285            9.9              0.59         0.07             3.4      0.102
# 956            9.0              0.36         0.52             2.1      0.111
# 935            8.8              0.30         0.38             2.3      0.060
# 36             7.8              0.60         0.14             2.4      0.086
# 822            6.7              0.54         0.13             2.0      0.076
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 285                 32.0                  71.0  1.00015  3.31       0.71
# 956                  5.0                  10.0  0.99568  3.31       0.62
# 935                 19.0                  72.0  0.99543  3.39       0.72
# 36                   3.0                  15.0  0.99750  3.42       0.60
# 822                 15.0                  36.0  0.99730  3.61       0.64
#
#      alcohol  quality NEW_NAME_citric_cat  y
# ...
